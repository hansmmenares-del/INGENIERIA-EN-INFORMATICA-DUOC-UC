# %% [markdown]
# # Formulario Python para MAT2121

# %% [markdown]
# ## Importar bibliotecas o librerías

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import fsolve

# %% [markdown]
# ## Manipulación de listas

# %%
lista = [1, 2, 3, 4]
primer_elemento = lista[0] #Muestra el 1
ultimo_elemento = lista[-1] #Muestra el 4

# %% [markdown]
# ## Definición de una función

# %%
#Por ejemplo, si la función es f(x)=4x:

def f(x):
    return 4*x

# %% [markdown]
# ## Evaluar una función

# %%
#Si queremos calcular f(5):

print(f(5))

#o con frase:
print(f'El resultado de f(5) es {f(5)}.')

# %% [markdown]
# ## Graficar una función

# %%
def f(x):
    return #aquí escribir la expresión de la función a graficar si no se ha definido antes

x = np.arange(valor inicial, valor final, paso)
plt.plot(x, f(x), label = 'f(x)')
plt.title('Nombre del gráfico')
plt.ylabel('Nombre eje y')
plt.xlabel('Nombre eje x')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## Encontrar la preimagen de una función
# (Resolver una ecuación)

# %%
def F(x):
    return #escribir la función igualada a cero

#Valor inicial de la aproximación:
x_inicial = 0
solucion = fsolve(F, x_inicial)

print(solucion)

# %% [markdown]
# ## Encontrar forma algebraica de una función lineal

# %%
x = np.array([valor 1, valor 2, valor 3, …, valor n])
y = np.array([valor 1, valor 2, valor 3, …, valor n])
#Si la función es de grado 1
pendiente, intercepto = np.polyfit(x, y, 1)

print(pendiente, intercepto)

# %% [markdown]
# ## Graficar limitando los ejes

# %%
def f(x):
    return #aquí escribir la expresión de la función a graficar si no se ha definido antes

x = np.arange(valor inicial, valor final, paso)
plt.plot(x, f(x), label = 'f(x)')
plt.title('Nombre del gráfico')
plt.ylabel('Nombre eje y')
plt.xlabel('Nombre eje x')

plt.ylim('mínimo y', 'máximo y')
plt.xlim('mínimo x', 'máximo x')

plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## Intersección de funciones
# (cuando puede haber más de una intersección)

# %%
#Definir la función igualada a cero
def inter(x):
    return f(x) - g(x)    #funciones definidas anteriormente

#Valores iniciales para la aproximación
x_inicial = np.linspace(a, b, n) #genera n valores iniciales distribuidos desde a hasta b

#Encontrar y redondear las soluciones
solucion = np.around(fsolve(inter, x_inicial), decimals=2)

#Eliminar soluciones repetidas
intersecciones = np.unique(solucion)

print(intersecciones)

#o con frase:
print(f'Los puntos de intersección de las funciones están en x = {intersecciones}.')

# %% [markdown]
# ## Operaciones especiales

# %% [markdown]
# $$e^{x}$$

# %%
np.exp(x)

# %% [markdown]
# $$\sqrt x$$

# %%
np.sqrt(x)

# %% [markdown]
# $$log(x)$$

# %%
np.log10(x)
